# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading and Preparing Data

# %%
df = pd.read_csv(f'weatherkit_plus_load.csv')
colors = sns.color_palette()

# %%
df.head(5)
# Out:
#              event_timestamp  weatherkit_observed_temperature_C  \
# 0  2023-02-11 00:30:00+05:30                              22.21
# 1  2023-02-11 00:45:00+05:30                              22.25
# 2  2023-02-11 01:00:00+05:30                              22.10
# 3  2023-02-11 01:15:00+05:30                              21.95
# 4  2023-02-11 01:30:00+05:30                              21.80
#
#    weatherkit_observed_humidity_pc  weatherkit_observed_air_pressure_kPa  \
# 0                             70.0                               101.357
# 1                             69.0                               101.354
# 2                             70.0                               101.344
# 3                             70.0                               101.333
# 4                             70.0                               101.322
#
#    weatherkit_observed_cloud_cover_pc  weatherkit_observed_wind_direction_deg  \
# 0                                 0.0                                   359.0
# 1                                 0.0                                     2.0
# 2                                 0.0                                     4.0
# 3                                 0.0                                     6.0
# 4                                 0.0                                     8.0
#
#    weatherkit_observed_wind_speed_km_h  weatherkit_forecast_temp_C  \
# 0                                 7.19                       21.99
# 1                                 7.25                       21.99
# 2                                 7.21                       21.99
# 3                                 7.15                       21.99
# 4                                 7.09                       21.35
#
#    weatherkit_forecast_humidity_pc  weatherkit_forecast_air_pressure_kPa  \
# 0                             72.0                               101.369
# 1                             72.0                               101.369
# 2                             72.0                               101.369
# 3                             72.0                               101.369
# 4                             73.0                               101.334
#
#    weatherkit_forecast_cloud_cover_pc  weatherkit_forecast_wind_direction_deg  \
# 0                                 0.0                                     1.0
# 1                                 0.0                                     1.0
# 2                                 0.0                                     1.0
# 3                                 0.0                                     1.0
# 4                                 0.0                                     6.0
#
#    weatherkit_forecast_wind_speed_km_h     load_MW
# 0                                 7.06  256.024088
# 1                                 7.06  251.899132
# 2                                 7.06  248.695780
# 3                                 7.06  245.879308
# 4                                 7.37  243.583376

# %%
#setting the dataframe index to timestampt
df = df.set_index('event_timestamp')

# %%
#converting object type to datetime
df.index = pd.to_datetime(df.index)

# %%
#Removing the initial text from column name
df.columns = df.columns.str.strip('weatherkit_')

# %%
ar_df = df.copy()

# %%
df.head(10)
# Out:
#                            observed_temperature_C  observed_humidity_pc  \
# event_timestamp
# 2023-02-11 00:30:00+05:30                   22.21                  70.0
# 2023-02-11 00:45:00+05:30                   22.25                  69.0
# 2023-02-11 01:00:00+05:30                   22.10                  70.0
# 2023-02-11 01:15:00+05:30                   21.95                  70.0
# 2023-02-11 01:30:00+05:30                   21.80                  70.0
# 2023-02-11 01:45:00+05:30                   21.66                  71.0
# 2023-02-11 02:00:00+05:30                   21.53                  71.0
# 2023-02-11 02:15:00+05:30                   21.39                  71.0
# 2023-02-11 02:30:00+05:30                   21.25                  72.0
# 2023-02-11 02:45:00+05:30                   21.05                  73.0
#
#                            observed_air_pressure_kP  observed_cloud_cover_pc  \
# event_timestamp
# 2023-02-11 00:30:00+05:30                   101.357                      0.0
# 2023-02-11 00:45:00+05:30                   101.354                      0.0
# 2023-02-11 01:00:00+05:30                   101.344                      0.0
# 2023-02-11 01:15:00+05:30                   101.333                      0.0
# 2023-02-11 01:30:00+05:30                   101.322                      0.0
# 2023-02-11 01:45:00+05:30                   101.313                      0.0
# 2023-02-11 02:00:00+05:30                   101.304                      0.0
# 2023-02-11 02:15:00+05:30                   101.295                      0.0
# 2023-02-11 02:30:00+05:30                   101.287                      0.0
# 2023-02-11 02:45:00+05:30                   101.280                      0.0
#
#                            observed_wind_direction_deg  \
# event_timestamp
# 2023-02-11 00:30:00+05:30                        359.0
# 2023-02-11 00:45:00+05:30                          2.0
# 2023-02-11 01:00:00+05:30                          4.0
# 2023-02-11 01:15:00+05:30                          6.0
# 2023-02-11 01:30:00+05:30                          8.0
# 2023-02-11 01:45:00+05:30                         10.0
# 2023-02-11 02:00:00+05:30                         12.0
# 2023-02-11 02:15:00+05:30                         13.0
# 2023-02-11 02:30:00+05:30                         15.0
# 2023-02-11 02:45:00+05:30                         16.0
#
#                            observed_wind_speed_km  forecast_temp_C  \
# event_timestamp
# 2023-02-11 00:30:00+05:30                    7.19            21.99
# 2023-02-11 00:45:00+05:30                    7.25            21.99
# 2023-02-11 01:00:00+05:30                    7.21            21.99
# 2023-02-11 01:15:00+05:30                    7.15            21.99
# 2023-02-11 01:30:00+05:30                    7.09            21.35
# 2023-02-11 01:45:00+05:30                    7.07            21.35
# 2023-02-11 02:00:00+05:30                    7.06            21.35
# 2023-02-11 02:15:00+05:30                    7.06            21.35
# 2023-02-11 02:30:00+05:30                    7.04            20.86
# 2023-02-11 02:45:00+05:30                    7.01            20.86
#
#                            forecast_humidity_pc  forecast_air_pressure_kP  \
# event_timestamp
# 2023-02-11 00:30:00+05:30                  72.0                   101.369
# 2023-02-11 00:45:00+05:30                  72.0                   101.369
# 2023-02-11 01:00:00+05:30                  72.0                   101.369
# 2023-02-11 01:15:00+05:30                  72.0                   101.369
# 2023-02-11 01:30:00+05:30                  73.0                   101.334
# 2023-02-11 01:45:00+05:30                  73.0                   101.334
# 2023-02-11 02:00:00+05:30                  73.0                   101.334
# 2023-02-11 02:15:00+05:30                  73.0                   101.334
# 2023-02-11 02:30:00+05:30                  74.0                   101.292
# 2023-02-11 02:45:00+05:30                  74.0                   101.292
#
#                            forecast_cloud_cover_pc  \
# event_timestamp
# 2023-02-11 00:30:00+05:30                      0.0
# 2023-02-11 00:45:00+05:30                      0.0
# 2023-02-11 01:00:00+05:30                      0.0
# 2023-02-11 01:15:00+05:30                      0.0
# 2023-02-11 01:30:00+05:30                      0.0
# 2023-02-11 01:45:00+05:30                      0.0
# 2023-02-11 02:00:00+05:30                      0.0
# 2023-02-11 02:15:00+05:30                      0.0
# 2023-02-11 02:30:00+05:30                      0.0
# 2023-02-11 02:45:00+05:30                      0.0
#
#                            forecast_wind_direction_deg  \
# event_timestamp
# 2023-02-11 00:30:00+05:30                          1.0
# 2023-02-11 00:45:00+05:30                          1.0
# 2023-02-11 01:00:00+05:30                          1.0
# 2023-02-11 01:15:00+05:30                          1.0
# 2023-02-11 01:30:00+05:30                          6.0
# 2023-02-11 01:45:00+05:30                          6.0
# 2023-02-11 02:00:00+05:30                          6.0
# 2023-02-11 02:15:00+05:30                          6.0
# 2023-02-11 02:30:00+05:30                         14.0
# 2023-02-11 02:45:00+05:30                         14.0
#
#                            forecast_wind_speed_km     load_MW
# event_timestamp
# 2023-02-11 00:30:00+05:30                    7.06  256.024088
# 2023-02-11 00:45:00+05:30                    7.06  251.899132
# 2023-02-11 01:00:00+05:30                    7.06  248.695780
# 2023-02-11 01:15:00+05:30                    7.06  245.879308
# 2023-02-11 01:30:00+05:30                    7.37  243.583376
# 2023-02-11 01:45:00+05:30                    7.37  242.830688
# 2023-02-11 02:00:00+05:30                    7.37  240.197572
# 2023-02-11 02:15:00+05:30                    7.37  238.021056
# 2023-02-11 02:30:00+05:30                    7.33  236.483380
# 2023-02-11 02:45:00+05:30                    7.33  234.128616

# %%
#Checking for any missing values
print(len(df))
print(df.isnull().values.sum())
df.describe()
# Out:
# 14298
# 0
#        observed_temperature_C  observed_humidity_pc  observed_air_pressure_kP  \
# count            14298.000000          14298.000000              14298.000000
# mean                28.877266             67.243768                100.902437
# std                  3.480119             16.161825                  0.321955
# min                 18.470000             21.000000                 99.866000
# 25%                 26.530000             56.999000                100.681000
# 50%                 28.740000             70.000000                100.915500
# 75%                 31.410000             80.000000                101.117000
# max                 38.390000             95.000000                101.760000
#
#        observed_cloud_cover_pc  observed_wind_direction_deg  \
# count             14298.000000                 14298.000000
# mean                 33.470323                   218.261505
# std                  30.138515                   106.989811
# min                   0.000000                     0.000000
# 25%                   9.000000                   173.000000
# 50%                  24.000000                   251.000000
# 75%                  52.000000                   297.000000
# max                  99.000000                   359.000000
#
#        observed_wind_speed_km  forecast_temp_C  forecast_humidity_pc  \
# count            14298.000000     14298.000000          14298.000000
# mean                11.394937        28.810426             67.022262
# std                  6.103925         3.479793             16.255389
# min                  1.730000        18.100000             20.000000
# 25%                  6.270000        26.440000             56.999000
# 50%                  9.970000        28.640000             70.000000
# 75%                 16.040000        31.350000             80.000000
# max                 35.200000        37.580000             95.000000
#
#        forecast_air_pressure_kP  forecast_cloud_cover_pc  \
# count              14298.000000             14298.000000
# mean                 100.893322                32.690287
# std                    0.315788                29.219298
# min                   99.964000                 0.000000
# 25%                  100.676000                10.000000
# 50%                  100.907000                24.000000
# 75%                  101.108000                48.000000
# max                  101.713000                99.000000
#
#        forecast_wind_direction_deg  forecast_wind_speed_km       load_MW
# count                 14298.000000            14298.000000  14298.000000
# mean                    217.872849               11.474569    372.500217
# std                     105.033661                6.068993     88.323996
# min                       0.000000                1.450000    214.677424
# 25%                     171.000000                6.360000    301.146656
# 50%                     249.000000               10.180000    356.875968
# 75%                     295.000000               16.340000    439.639653
# max                     359.000000               32.990000   1543.524320

# %% [markdown]
# # Data Analysis and Feature Engineering

# %%
#correlation between features
corr = df.corr()
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr, annot=True, cmap=sns.color_palette('Greens'))

# %% [markdown]
# The heatmap shows minimal correlation between the target and cloud cover.
# The key attributes are temperature and windspeed.
# There is also a high correlation between the observed values and the forecasted.

# %%
#Only using forecasted values and not observed and dropping cloud_cover
cols = list(df.columns)
df = df[cols[6:]]
df.drop(['forecast_cloud_cover_pc'], axis=1, inplace=True)
lstm_df = df.copy()

# %%
df.isnull().any().any()
# Out:
# False

# %%
#Visualizing the target variable
df['load_MW'].plot(color=colors[0], figsize=(10,5), title='Load')
# Out:
# <Axes: title={'center': 'Load'}, xlabel='event_timestamp'>

# %% [markdown]
# Seasonality is observed with repeating patterns
# Further exploring days and weeks.

# %%
day = df.loc[(df.index >= '2023-03-01 00:00:00+5:30') & (df.index < '2023-03-02 00:00:00+5:30'), 'load_MW']
day.plot(title='Load for one day')
# Out:
# <Axes: title={'center': 'Load for one day'}, xlabel='event_timestamp'>

# %%
week = df.loc[(df.index >= '2023-03-01 00:00:00+5:30') & (df.index < '2023-03-15 00:00:00+5:30'), 'load_MW']
week.plot(title='Load for two weeks')
# Out:
# <Axes: title={'center': 'Load for two weeks'}, xlabel='event_timestamp'>

# %%
#Adding Load from 48 hours ago and 7 days ago (same day) at the same time
df['PrevDay'] = df['load_MW'].shift(freq='2D')
df['PrevWeek'] = df['load_MW'].shift(freq='7D')
df.dropna(inplace=True)

# %% [markdown]
# Day of the week and Hour of the day seem to have effect on the load

# %%
#Creating new features
df['Hour'] = df.index.hour
df['Day'] = df.index.dayofweek

# %% [markdown]
# # Model Selection

# %%
X = df.drop(['load_MW'], axis=1)
y = df['load_MW']

# %%
#Train-Test Split
train_size = int(0.8*len(df))
X_train = X.iloc[:train_size]
X_test = X.iloc[train_size:]
y_train = y.iloc[:train_size]
y_test = y.iloc[train_size:]

# %%
fig, ax = plt.subplots()
train = ax.plot(y_train, label='Training')
test = ax.plot(y_test, label='Testing')
plt.legend()
plt.show()

# %% [markdown]
# ### Using Regression for Predictions

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
model = xgb.XGBRegressor(n_estimators=500, early_stopping_rounds=100, learning_rate=0.01, random_state=42)
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=100)
preds = model.predict(X_test)
mse_score = mean_squared_error(preds, y_test)
mape_score = mean_absolute_percentage_error(preds, y_test)
# Out:
# [0]	validation_0-rmse:86.97643	validation_1-rmse:91.52750
# [100]	validation_0-rmse:39.69265	validation_1-rmse:45.93821
# [200]	validation_0-rmse:24.26865	validation_1-rmse:34.40357
# [300]	validation_0-rmse:18.83555	validation_1-rmse:32.41467
# [400]	validation_0-rmse:15.96740	validation_1-rmse:32.68325
# [449]	validation_0-rmse:14.97695	validation_1-rmse:32.46987

# %%
print('Mean Squared Error: ', mse_score)
print("RMSE: ", np.sqrt(mse_score))
# Out:
# Mean Squared Error:  1021.7605679803081
# RMSE:  31.964989722825003

# %%
print('Mean Absolute Percentage Error: ', mape_score)
# Out:
# Mean Absolute Percentage Error:  0.06228469772452729

# %% [markdown]
# Feature Importance Analysis

# %%
importances = dict(zip(model.feature_names_in_,model.feature_importances_))
imps = df.from_dict(importances, orient='index', columns=['Score'])

# %%
imps.sort_values(['Score'])
# Out:
#                                 Score
# forecast_wind_speed_km       0.013267
# forecast_air_pressure_kP     0.013661
# forecast_wind_direction_deg  0.013734
# forecast_humidity_pc         0.020656
# Hour                         0.025629
# Day                          0.031125
# forecast_temp_C              0.045372
# PrevDay                      0.091472
# PrevWeek                     0.745084

# %% [markdown]
# Plotting Predicted vs. Real Values

# %%
x = np.arange(len(preds))

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x, y_test, label='Observed')
ax.plot(x, preds, label='Predicted')
plt.title('GB Regressor')
plt.legend()
plt.show()

# %% [markdown]
# # Using LSTMs for comparison to Regressor

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#                            forecast_temp_C  forecast_humidity_pc  \
# event_timestamp
# 2023-02-18 00:30:00+05:30            25.33                  42.0
# 2023-02-18 00:45:00+05:30            25.33                  42.0
# 2023-02-18 01:00:00+05:30            25.33                  42.0
# 2023-02-18 01:15:00+05:30            25.33                  42.0
# 2023-02-18 01:30:00+05:30            24.42                  43.0
#
#                            forecast_air_pressure_kP  \
# event_timestamp
# 2023-02-18 00:30:00+05:30                   101.204
# 2023-02-18 00:45:00+05:30                   101.204
# 2023-02-18 01:00:00+05:30                   101.204
# 2023-02-18 01:15:00+05:30                   101.204
# 2023-02-18 01:30:00+05:30                   101.164
#
#                            forecast_wind_direction_deg  \
# event_timestamp
# 2023-02-18 00:30:00+05:30                         39.0
# 2023-02-18 00:45:00+05:30                         39.0
# 2023-02-18 01:00:00+05:30                         39.0
# 2023-02-18 01:15:00+05:30                         39.0
# 2023-02-18 01:30:00+05:30                         48.0
#
#                            forecast_wind_speed_km     load_MW     PrevDay  \
# event_timestamp
# 2023-02-18 00:30:00+05:30                    7.60  284.676756  266.299720
# 2023-02-18 00:45:00+05:30                    7.60  280.063324  262.751976
# 2023-02-18 01:00:00+05:30                    7.60  276.169996  258.501784
# 2023-02-18 01:15:00+05:30                    7.60  273.667292  254.857032
# 2023-02-18 01:30:00+05:30                    7.65  269.280432  252.261184
#
#                              PrevWeek  Hour  Day
# event_timestamp
# 2023-02-18 00:30:00+05:30  256.024088     0    5
# 2023-02-18 00:45:00+05:30  251.899132     0    5
# 2023-02-18 01:00:00+05:30  248.695780     1    5
# 2023-02-18 01:15:00+05:30  245.879308     1    5
# 2023-02-18 01:30:00+05:30  243.583376     1    5

# %%
lstmdf = df.copy()
lstmdf = lstmdf.iloc[:, [0,1,2,3,4,6,7,8,5]] #Rearranging DF
train_size = int(0.8*len(lstmdf))
train_df = lstmdf.iloc[:train_size]
test_df = lstmdf.iloc[train_size:]
train_df = scaler.fit_transform(train_df)
test_df = scaler.transform(test_df)
X_train = train_df[:,:-1]
y_train = train_df[:,-1]
X_test = test_df[:,:-1]
y_test = test_df[:, -1]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10793, 8)
# (2699, 8)
# (10793,)
# (2699,)

# %%
#Creating Sequences for the Model
window = 96 #To generate next day load only based on forecasted values and historic values
X, y = [], []
for i in range(len(X_train) - window):
    X.append(X_train[i:i+window])
    y.append(y_train[i:i+window])

Xt, yt = [], []
for i in range(len(X_test) - window):
    Xt.append(X_test[i:i+window])
    yt.append(y_test[i:i+window])
X = torch.tensor(np.array(X), dtype=torch.float32)
y = torch.tensor(np.array(y), dtype=torch.float32)
Xt = torch.tensor(np.array(Xt), dtype=torch.float32)
yt = torch.tensor(np.array(yt), dtype=torch.float32)
print(X.shape, y.shape)
print(Xt.shape, yt.shape)
# Out:
# torch.Size([10697, 96, 8]) torch.Size([10697, 96])
# torch.Size([2603, 96, 8]) torch.Size([2603, 96])

# %%
#Preparing the torch dataset
train_dataset = TensorDataset(X, y)
test_dataset = TensorDataset(Xt, yt)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=8, num_layers=2, hidden_size=128, batch_first=True, dropout=0.2)
        self.fc = nn.Linear(128, 96)
    def forward(self, x):
        x, (hstate, cstate) = self.lstm(x)
        #Could also consider Mean Pooling (e.g. x = torch.mean(x, dim=1)) instead of only extracting hidden states from the last time step.
        out = self.fc(x[:,-1,:])
        return out

# %%
model = LSTM()
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5)
epochs = 20

# %%
train_loss, test_loss = [], []
for epoch in tqdm(range(epochs), leave=True):
    running_loss = 0.0
    model.train()
    for X, y in train_loader:
        X = X.to(device)
        y = y.to(device)
        preds = model(X)
        loss = criterion(preds, y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        running_loss += loss.item() * X.shape[0]
    train_loss.append(running_loss)
    print('Training Loss: {}'.format(running_loss))
    model.eval()
    with torch.no_grad():
        running_loss = 0.0
        for X, y in test_loader:
            X = X.to(device)
            y = y.to(device)
            preds = model(X)
            loss = criterion(preds, y)
            running_loss += loss.item() * X.shape[0]
        scheduler.step(running_loss)
        test_loss.append(running_loss)
        print('Validation Loss: {}'.format(running_loss))
# Out:
#   5%|▌         | 1/20 [00:01<00:19,  1.01s/it]
# Training Loss: 22.254072394687682
# Validation Loss: 1.914706360315904
#  10%|█         | 2/20 [00:01<00:16,  1.12it/s]
# Training Loss: 10.306903963442892
# Validation Loss: 1.9864667446818203
#  15%|█▌        | 3/20 [00:02<00:14,  1.20it/s]
# Training Loss: 8.520566569990478
# Validation Loss: 1.7088848374551162
#  20%|██        | 4/20 [00:03<00:13,  1.22it/s]
# Training Loss: 7.639006001409143
# Validation Loss: 1.6542201754637063
#  25%|██▌       | 5/20 [00:04<00:12,  1.23it/s]
# Training Loss: 7.391772965784185
# Validation Loss: 1.8397615387220867
#  30%|███       | 6/20 [00:04<00:11,  1.24it/s]
# Training Loss: 6.816336283460259
# Validation Loss: 1.3232603867072612
#  35%|███▌      | 7/20 [00:05<00:10,  1.24it/s]
# Training Loss: 6.727254031924531
# Validation Loss: 1.5454541061189957
#  40%|████      | 8/20 [00:06<00:09,  1.26it/s]
# Training Loss: 6.418631850101519
# Validation Loss: 1.832235766283702
#  45%|████▌     | 9/20 [00:07<00:08,  1.27it/s]
# Training Loss: 6.0143595861736685
# Validation Loss: 1.4369923386257142
#  50%|█████     | 10/20 [00:08<00:07,  1.27it/s]
# Training Loss: 5.621826191942091
# Validation Loss: 1.341420415788889
#  55%|█████▌    | 11/20 [00:08<00:07,  1.26it/s]
# Training Loss: 5.6476056050742045
# Validation Loss: 1.896694908151403
#  60%|██████    | 12/20 [00:09<00:06,  1.27it/s]
# Training Loss: 5.291959003545344
# Validation Loss: 1.3251475914148614
#  65%|██████▌   | 13/20 [00:10<00:05,  1.28it/s]
# Training Loss: 4.414882444543764
# Validation Loss: 1.420622454606928
#  70%|███████   | 14/20 [00:11<00:04,  1.28it/s]
# Training Loss: 4.149879841483198
# Validation Loss: 1.4785376174841076
#  75%|███████▌  | 15/20 [00:12<00:03,  1.29it/s]
# Training Loss: 4.014561036783562
# Validation Loss: 1.6369376132497564
#  80%|████████  | 16/20 [00:12<00:03,  1.29it/s]
# Training Loss: 3.773572674850584
# Validation Loss: 1.6913739459123462
#  85%|████████▌ | 17/20 [00:13<00:02,  1.30it/s]
# Training Loss: 3.651273111696355
# Validation Loss: 1.8333081441232935
#  90%|█████████ | 18/20 [00:14<00:01,  1.30it/s]
# Training Loss: 3.593791912411689
# Validation Loss: 1.854181918897666
#  95%|█████████▌| 19/20 [00:15<00:00,  1.31it/s]
# Training Loss: 3.4539558215037687
# Validation Loss: 1.8084133976371959
# 100%|██████████| 20/20 [00:15<00:00,  1.27it/s]
# Training Loss: 3.4267134364927188
# Validation Loss: 1.8066331923473626

# %%
predicted, observed = [], []
model.eval()
with torch.no_grad():
    for i in range(0, len(Xt), 96):
        sequence = Xt[i].unsqueeze(0).to(device)            #Changing 2D to 3D for LSTM
        preds = model(sequence).cpu().numpy().flatten()
        predicted.append(preds)
        observed.append(yt[i].cpu().numpy().flatten())

# %%
Xt.shape
# Out:
# torch.Size([2603, 96, 8])

# %%
#Inverting the scaler to get the real values
predicted = np.array(predicted).flatten()
observed = np.array(observed).flatten()
dummy = np.zeros((predicted.shape[0], Xt.shape[2])) #Dummy columns to match the shape for the scaler
print(dummy.shape)
predicted = scaler.inverse_transform(np.concatenate([dummy, predicted.reshape(-1,1)], axis=1))
observed = scaler.inverse_transform(np.concatenate([dummy, observed.reshape(-1,1)], axis=1))
# Out:
# (2688, 8)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(observed[:,-1], label='Observed')
ax.plot(predicted[:,-1], label='Predicted')
plt.title('LSTM Output')
plt.legend()
plt.show()

# %%
MSE = mean_squared_error(observed[:,-1], predicted[:,-1])
RMSE = np.sqrt(MSE)
MAPE = mean_absolute_percentage_error(observed[:,-1], predicted[:,-1])
print(MSE, RMSE, MAPE)
# Out:
# 1310.4166598841223 36.1996776212734 0.06783091883664645

# %% [markdown]
# # Using LSTMs for Predictions (Future Prediction)

# %% [markdown]
# Data Preparation

# %%
#Train-Test Split and scaling
scaler = MinMaxScaler()
lstm_df['PrevWeek'] = lstm_df['load_MW'].shift(freq='6D')   #adding the reading from the same day last week
lstm_df.dropna(inplace=True)
lstm_df = lstm_df.iloc[:, [0,1,2,3,4,6,5]]
train_size = int(0.8*len(lstm_df))
train_df = lstm_df.iloc[:train_size]
test_df = lstm_df.iloc[train_size:]
train_df = scaler.fit_transform(train_df)
test_df = scaler.transform(test_df)
X_train = train_df[:,:-1]
y_train = train_df[:,-1]
X_test = test_df[:,:-1]
y_test = test_df[:, -1]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10922, 6)
# (2731, 6)
# (10922,)
# (2731,)

# %%
#Creating Sequences for the Model
window = 160 #To generate next day load plus today's load after 8:00AM
X, y = [], []
for i in range(len(X_train) - (window*2)):
    X.append(X_train[i:i+window])
    y.append(y_train[i+window:i+window+window])

Xt, yt = [], []
for i in range(len(X_test) - (window*2)):
    Xt.append(X_test[i:i+window])
    yt.append(y_test[i+window:i+window+window])
X = torch.tensor(np.array(X), dtype=torch.float32)
y = torch.tensor(np.array(y), dtype=torch.float32)
Xt = torch.tensor(np.array(Xt), dtype=torch.float32)
yt = torch.tensor(np.array(yt), dtype=torch.float32)
print(X.shape, y.shape)
print(Xt.shape, yt.shape)
# Out:
# torch.Size([10602, 160, 6]) torch.Size([10602, 160])
# torch.Size([2411, 160, 6]) torch.Size([2411, 160])

# %%
#Preparing the torch dataset
train_dataset = TensorDataset(X, y)
test_dataset = TensorDataset(Xt, yt)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
len(train_dataset)
# Out:
# 10602

# %% [markdown]
# Defining Model

# %%
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=6, num_layers=2, hidden_size=128, batch_first=True, dropout=0.2)
        self.fc = nn.Linear(128, 160)
    def forward(self, x):
        x, (hstate, cstate) = self.lstm(x)
        out = self.fc(x[:,-1,:])
        return out

# %%
model = LSTM()
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5)
epochs = 20

# %% [markdown]
# Training the model

# %%
train_loss, test_loss = [], []
for epoch in tqdm(range(epochs), leave=True):
    running_loss = 0.0
    model.train()
    for X, y in train_loader:
        X = X.to(device)
        y = y.to(device)
        preds = model(X)
        loss = criterion(preds, y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        running_loss += loss.item() * X.shape[0]
    train_loss.append(running_loss)
    print('Training Loss: {}'.format(running_loss))
    model.eval()
    with torch.no_grad():
        running_loss = 0.0
        for X, y in test_loader:
            X = X.to(device)
            y = y.to(device)
            preds = model(X)
            loss = criterion(preds, y)
            running_loss += loss.item() * X.shape[0]
        scheduler.step(running_loss)
        test_loss.append(running_loss)
        print('Validation Loss: {}'.format(running_loss))
# Out:
#   5%|▌         | 1/20 [00:01<00:20,  1.05s/it]
# Training Loss: 25.571120099863037
# Validation Loss: 3.43531661760062
#  10%|█         | 2/20 [00:02<00:18,  1.05s/it]
# Training Loss: 12.992005828535184
# Validation Loss: 2.5418748140800744
#  15%|█▌        | 3/20 [00:03<00:17,  1.06s/it]
# Training Loss: 11.563907388597727
# Validation Loss: 2.1173861117567867
#  20%|██        | 4/20 [00:04<00:16,  1.06s/it]
# Training Loss: 10.586752070114017
# Validation Loss: 3.028610701672733
#  25%|██▌       | 5/20 [00:05<00:15,  1.06s/it]
# Training Loss: 9.257488796953112
# Validation Loss: 3.13001922366675
#  30%|███       | 6/20 [00:06<00:14,  1.06s/it]
# Training Loss: 8.467500118771568
# Validation Loss: 2.3875824798014946
#  35%|███▌      | 7/20 [00:07<00:13,  1.06s/it]
# Training Loss: 10.411164974560961
# Validation Loss: 2.9860117030330002
#  40%|████      | 8/20 [00:08<00:12,  1.07s/it]
# Training Loss: 8.873959523625672
# Validation Loss: 3.503401515772566
#  45%|████▌     | 9/20 [00:09<00:11,  1.07s/it]
# Training Loss: 9.375418256036937
# Validation Loss: 6.338018890004605
#  50%|█████     | 10/20 [00:10<00:10,  1.05s/it]
# Training Loss: 6.89935338543728
# Validation Loss: 5.056699462933466
#  55%|█████▌    | 11/20 [00:11<00:09,  1.03s/it]
# Training Loss: 6.581694640975911
# Validation Loss: 5.581804650602862
#  60%|██████    | 12/20 [00:12<00:08,  1.02s/it]
# Training Loss: 6.387015955115203
# Validation Loss: 6.3430700222961605
#  65%|██████▌   | 13/20 [00:13<00:07,  1.01s/it]
# Training Loss: 6.171919581247494
# Validation Loss: 6.088623416610062
#  70%|███████   | 14/20 [00:14<00:05,  1.00it/s]
# Training Loss: 6.08937647100538
# Validation Loss: 6.614015795756131
#  75%|███████▌  | 15/20 [00:15<00:04,  1.01it/s]
# Training Loss: 6.004983886377886
# Validation Loss: 6.5303441600408405
#  80%|████████  | 16/20 [00:16<00:03,  1.01it/s]
# Training Loss: 5.823539202858228
# Validation Loss: 6.949679809622467
#  85%|████████▌ | 17/20 [00:17<00:02,  1.01it/s]
# Training Loss: 5.789641062263399
# Validation Loss: 7.069356374442577
#  90%|█████████ | 18/20 [00:18<00:01,  1.01it/s]
# Training Loss: 5.785109765827656
# Validation Loss: 7.132711039856076
#  95%|█████████▌| 19/20 [00:19<00:00,  1.00it/s]
# Training Loss: 5.756810985243646
# Validation Loss: 7.114873089827597
# 100%|██████████| 20/20 [00:20<00:00,  1.02s/it]
# Training Loss: 5.754312229750212
# Validation Loss: 7.100889601744711

# %% [markdown]
# Making Predictions on the test set

# %%
predicted, observed = [], []
model.eval()
with torch.no_grad():
    for i in range(0, len(Xt), 160):
        sequence = Xt[i].unsqueeze(0).to(device)            #Changing 2D to 3D for LSTM
        preds = model(sequence).cpu().numpy().flatten()
        predicted.append(preds)
        observed.append(yt[i].cpu().numpy().flatten())

# %%
#Inverting the scaler to get the real values
predicted = np.array(predicted).flatten()
observed = np.array(observed).flatten()
dummy = np.zeros((predicted.shape[0], Xt.shape[2])) #Dummy columns to match the shape for the scaler
print(dummy.shape)
predicted = scaler.inverse_transform(np.concatenate([dummy, predicted.reshape(-1,1)], axis=1))
observed = scaler.inverse_transform(np.concatenate([dummy, observed.reshape(-1,1)], axis=1))
# Out:
# (2560, 6)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(observed[:,-1], label='Observed')
ax.plot(predicted[:,-1], label='Predicted')
plt.title('LSTM (Future Predictions)')
plt.legend()
plt.show()

# %%
MSE = mean_squared_error(observed[:,-1], predicted[:,-1])
RMSE = np.sqrt(MSE)
MAPE = mean_absolute_percentage_error(observed[:,-1], predicted[:,-1])
print(MSE, RMSE, MAPE)
# Out:
# 4675.072447182541 68.37450144010222 0.12024668264092524

# %% [markdown]
# ### Using ARIMA for Time-Series Forecasting

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import pmdarima

# %%
#Skipping the first day as it did not have values starting from 00:00:00
timeseries = ar_df.loc[(ar_df.index >= '2023-02-12'), 'load_MW']

# %%
#Checking for stationarity using the ADF Test
results = adfuller(timeseries)
print('ADF: ', results[0])
print('P-value: ', results[1]) #The p-value is very small, i.e., smaller than 5% so no stationarity
# Out:
# ADF:  -16.216433776870876
# P-value:  3.938121056311996e-29

# %%
timeseries
train_size = int(0.8*len(timeseries))
train = timeseries.iloc[:train_size]
test = timeseries.iloc[train_size:]

# %%
acf = plot_acf(timeseries) #Shows gradual decay and no sharp cut-off

# %%
pacf = plot_pacf(timeseries) #Shows a strong cutoff after 2

# %% [markdown]
# Automatically finding the best model parameters for ARIMA was not feasible

# %%
#params = pmdarima.auto_arima(train, d=0, stepwise=True, trace=True, max_order=6, suppress_warnings=True)

# %%
# %%capture
#Using an autoregressive based model based on the previous plots
model = ARIMA(train, order=(5,1,1))
result = model.fit()

# %%
print(result.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                load_MW   No. Observations:                11363
# Model:                 ARIMA(5, 1, 1)   Log Likelihood              -48202.814
# Date:                Mon, 10 Mar 2025   AIC                          96419.629
# Time:                        17:20:53   BIC                          96470.995
# Sample:                             0   HQIC                         96436.906
#                               - 11363
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6435      0.006    107.593      0.000       0.632       0.655
# ar.L2          0.0816      0.001     70.180      0.000       0.079       0.084
# ar.L3          0.0325      0.002     15.970      0.000       0.028       0.036
# ar.L4         -0.0585      0.001    -44.886      0.000      -0.061      -0.056
# ar.L5          0.1577      0.002     81.037      0.000       0.154       0.162
# ma.L1         -0.7622      0.006   -121.940      0.000      -0.774      -0.750
# sigma2       283.4450      0.161   1755.258      0.000     283.128     283.761
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.63   Jarque-Bera (JB):        1700648369.37
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):              35.26   Skew:                            10.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                      1898.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
